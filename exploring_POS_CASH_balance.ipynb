# %%
import pandas as pd
df =  pd.read_csv('./data/POS_CASH_balance.csv')

# %%
df.sort_values(['SK_ID_PREV', 'MONTHS_BALANCE'])
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 6030662     1000001      158271             -10            12.0
# 8470736     1000001      158271              -9            12.0
# 45995       1000001      158271              -8             2.0
# 4467804     1000002      101962             -54             4.0
# 3346102     1000002      101962             -53             6.0
# ...             ...         ...             ...             ...
# 5675189     2843499      314148             -34            60.0
# 1722726     2843499      314148             -33            60.0
# 804539      2843499      314148             -32            60.0
# 5580339     2843499      314148             -31            10.0
# 8600392     2843499      314148             -30            10.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 6030662                   12.0               Active       0           0
# ...

# %%
pd.get_dummies(df)
# Out:
#           SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0            1803195      182943             -31            48.0
# 1            1715348      367990             -33            36.0
# 2            1784872      397406             -32            12.0
# 3            1903291      269225             -35            48.0
# 4            2341044      334279             -35            36.0
# ...              ...         ...             ...             ...
# 10001353     2448283      226558             -20             6.0
# 10001354     1717234      141565             -19            12.0
# 10001355     1283126      315695             -21            10.0
# 10001356     1082516      450255             -22            12.0
# 10001357     1259607      174278             -52            16.0
#
#           CNT_INSTALMENT_FUTURE  SK_DPD  SK_DPD_DEF  \
# 0                          45.0       0           0
# 1                          35.0       0           0
# ...

# %%
df_summarized = df[['SK_ID_PREV','SK_ID_CURR', 'MONTHS_BALANCE', 'CNT_INSTALMENT', 'CNT_INSTALMENT_FUTURE']]

# %%
df_summarized.to_csv('./treated_data/POS_CASH_balance.csv',index=False)
