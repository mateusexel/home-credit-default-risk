# %%
import pandas as pd
import numpy as np
import gc
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
app =  pd.read_csv('../data/application_train.csv')[['SK_ID_CURR','TARGET']]
# credit_card_balance =  pd.read_csv('../data/credit_card_balance.csv')[['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'NAME_CONTRACT_STATUS', 'SK_DPD', 'SK_DPD_DEF']]
POS_CASH_balance =  pd.read_csv('../data/POS_CASH_balance.csv')
installments_payments =  pd.read_csv('../data/installments_payments.csv')

installments_payments['MONTHS_BALANCE'] = (installments_payments['DAYS_INSTALMENT']/30).round().astype(int)

# %% [markdown]
# ## Merge time series DFS

# %%
df = pd.merge(app,pd.merge(installments_payments, POS_CASH_balance , how='left'),how='inner')
df = df[df['MONTHS_BALANCE']>-80]

# %% [markdown]
# ## Resampling imbalance

# %%
count_class_0, count_class_1 = df.TARGET.value_counts()
df_class_0 = df[df['TARGET'] == 0]
df_class_1 = df[df['TARGET'] == 1]

df_class_0_under = df_class_0.sample(count_class_1)
df = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df.TARGET.value_counts())

df.TARGET.value_counts().plot(kind='bar', title='Count (target)');

# %% [markdown]
# ## Fillna(mean)

# %%
df = df.fillna(df.mean)

# %% [markdown]
# ## Select features with most corr with TARGET

# %%
main_features = df.groupby('SK_ID_CURR').mean().corr()['TARGET'].abs().sort_values(ascending=False)[1:7].keys()

# %%
main_features
# Out:
# Index(['DAYS_INSTALMENT', 'MONTHS_BALANCE', 'NUM_INSTALMENT_NUMBER',
#        'NUM_INSTALMENT_VERSION', 'AMT_INSTALMENT', 'SK_ID_PREV'],
#       dtype='object')

# %%
main_features=main_features.drop('MONTHS_BALANCE')

# %% [markdown]
# ## Normalize df

# %%
del POS_CASH_balance ,installments_payments, app
gc.collect()
# Out:
# 3035

# %%
df.shape
# Out:
# (1646128, 15)

# %% [markdown]
# ## Pivot months

# %%
df_pivot = df.pivot_table(values=main_features, index=['SK_ID_CURR','TARGET'], columns='MONTHS_BALANCE')
# Out:
#                   AMT_INSTALMENT                                              \
# MONTHS_BALANCE               -79 -78 -77 -76      -75 -74 -73        -72 -71
# SK_ID_CURR TARGET
# 100002     1                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 100003     0                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 100006     0                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 100007     0                 NaN NaN NaN NaN  1834.29 NaN NaN        NaN NaN
# 100008     0                 NaN NaN NaN NaN      NaN NaN NaN  12144.285 NaN
# ...                          ...  ..  ..  ..      ...  ..  ..        ...  ..
# 456248     0                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 456249     0                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 456251     0                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 456254     1                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
# 456255     0                 NaN NaN NaN NaN      NaN NaN NaN        NaN NaN
#
#                        ... SK_ID_PREV                                   \
# MONTHS_BALANCE    -70  ...        -9         -8         -7         -6
# SK_ID_CURR TARGET      ...
# 100002     1      NaN  ...  1038818.0  1038818.0  1038818.0  1038818.0
# 100003     0      NaN  ...        NaN        NaN        NaN        NaN
# 100006     0      NaN  ...        NaN        NaN        NaN        NaN
# 100007     0      NaN  ...        NaN        NaN        NaN        NaN
# 100008     0      NaN  ...        NaN        NaN        NaN        NaN
# ...                ..  ...        ...        ...        ...        ...
# 456248     0      NaN  ...        NaN        NaN        NaN        NaN
# 456249     0      NaN  ...        NaN        NaN        NaN        NaN
# 456251     0      NaN  ...        NaN        NaN        NaN        NaN
# 456254     1      NaN  ...  1792910.0  1904658.5  1904658.5  1904658.5
# 456255     0      NaN  ...  2631384.0  1995234.0  2631384.0        NaN
#
#                                                                           \
# MONTHS_BALANCE           -5         -4         -3         -2         -1
# SK_ID_CURR TARGET
# 100002     1       1038818.0  1038818.0  1038818.0  1038818.0  1038818.0
# 100003     0             NaN        NaN        NaN        NaN        NaN
# 100006     0             NaN        NaN        NaN        NaN        NaN
# 100007     0             NaN        NaN        NaN        NaN        NaN
# 100008     0             NaN        NaN        NaN        NaN        NaN
# ...                      ...        ...        ...        ...        ...
# 456248     0             NaN        NaN        NaN        NaN  1136073.0
# 456249     0             NaN        NaN        NaN        NaN        NaN
# 456251     0             NaN        NaN  2248017.0        NaN        NaN
# 456254     1       1904658.5  1904658.5  1904658.5  1904658.5  1904658.5
# 456255     0             NaN        NaN        NaN        NaN        NaN
#
#
# MONTHS_BALANCE            0
# SK_ID_CURR TARGET
# 100002     1             NaN
# 100003     0             NaN
# 100006     0             NaN
# 100007     0             NaN
# 100008     0             NaN
# ...                      ...
# 456248     0             NaN
# 456249     0             NaN
# 456251     0             NaN
# 456254     1       2016407.0
# 456255     0             NaN
#
# [233492 rows x 400 columns]

# %% [markdown]
# # resampling

# %%
count_class_0, count_class_1 = df.TARGET.value_counts()
df_class_0 = df[df['TARGET'] == 0]
df_class_1 = df[df['TARGET'] == 1]

df_class_0_under = df_class_0.sample(count_class_1)
df = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df.TARGET.value_counts())

df.TARGET.value_counts().plot(kind='bar', title='Count (target)');

# %%
df_pivot=df_pivot.fillna(0)

# %%
main_features
# Out:
# Index(['DAYS_INSTALMENT', 'NUM_INSTALMENT_NUMBER', 'NUM_INSTALMENT_VERSION',
#        'AMT_INSTALMENT', 'SK_ID_PREV'],
#       dtype='object')

# %%
y = df[['SK_ID_CURR','TARGET']].groupby('SK_ID_CURR').mean()['TARGET']

x = df_pivot.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_pivot = pd.DataFrame(x_scaled)

# %%
df
# Out:
#           SK_ID_CURR  TARGET  SK_ID_PREV  NUM_INSTALMENT_VERSION  \
# 681661        121437       0     1423432                     1.0
# 628496        119840       0     2388502                     0.0
# 10837378      432947       0     1387656                     1.0
# 130742        104077       0     1526234                     1.0
# 11159996      442864       0     2233876                     1.0
# ...              ...     ...         ...                     ...
# 11591513      456254       1     1792910                     1.0
# 11591514      456254       1     2016407                     1.0
# 11591515      456254       1     1792910                     1.0
# 11591516      456254       1     1792910                     1.0
# 11591517      456254       1     2016407                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT DAYS_ENTRY_PAYMENT  \
# 681661                        5           -347.0             -358.0
# 628496                      102           -561.0             -561.0
# 10837378                      2           -817.0             -810.0
# 130742                        9          -1444.0            -1430.0
# 11159996                      6           -530.0             -539.0
# ...                         ...              ...                ...
# 11591513                      4           -201.0             -232.0
# 11591514                      9             -7.0              -18.0
# 11591515                      2           -261.0             -277.0
# 11591516                      7           -111.0             -135.0
# 11591517                      5           -127.0             -135.0
#
#           AMT_INSTALMENT AMT_PAYMENT  MONTHS_BALANCE  \
# 681661         22247.505   22247.505             -12
# 628496           651.510      651.51             -19
# 10837378       22250.205       85.41             -27
# 130742         12869.820        7.56             -48
# 11159996       31446.360    31446.36             -18
# ...                  ...         ...             ...
# 11591513        2296.440     2296.44              -7
# 11591514       19065.825   19065.825               0
# 11591515        2296.440     2296.44              -9
# 11591516        2296.440     2296.44              -4
# 11591517       19065.825   19065.825              -4
#
#                                              CNT_INSTALMENT  \
# 681661                                                 30.0
# 628496    <bound method NDFrame._add_numeric_operations....
# 10837378                                               12.0
# 130742                                                 24.0
# 11159996                                               24.0
# ...                                                     ...
# 11591513                                               14.0
# 11591514  <bound method NDFrame._add_numeric_operations....
# 11591515                                               14.0
# 11591516                                               14.0
# 11591517                                               16.0
#
#                                       CNT_INSTALMENT_FUTURE  \
# 681661                                                 26.0
# 628496    <bound method NDFrame._add_numeric_operations....
# 10837378                                               10.0
# 130742                                                 16.0
# 11159996                                               18.0
# ...                                                     ...
# 11591513                                               10.0
# 11591514  <bound method NDFrame._add_numeric_operations....
# 11591515                                               12.0
# 11591516                                                7.0
# 11591517                                               11.0
#
#                                        NAME_CONTRACT_STATUS  \
# 681661                                               Active
# 628496    <bound method NDFrame._add_numeric_operations....
# 10837378                                             Active
# 130742                                               Active
# 11159996                                             Active
# ...                                                     ...
# 11591513                                             Active
# 11591514  <bound method NDFrame._add_numeric_operations....
# 11591515                                             Active
# 11591516                                             Active
# 11591517                                             Active
#
#                                                      SK_DPD  \
# 681661                                                  0.0
# 628496    <bound method NDFrame._add_numeric_operations....
# 10837378                                                1.0
# 130742                                                  0.0
# 11159996                                                0.0
# ...                                                     ...
# 11591513                                                0.0
# 11591514  <bound method NDFrame._add_numeric_operations....
# 11591515                                                0.0
# 11591516                                                0.0
# 11591517                                                0.0
#
#                                                  SK_DPD_DEF
# 681661                                                  0.0
# 628496    <bound method NDFrame._add_numeric_operations....
# 10837378                                                1.0
# 130742                                                  0.0
# 11159996                                                0.0
# ...                                                     ...
# 11591513                                                0.0
# 11591514  <bound method NDFrame._add_numeric_operations....
# 11591515                                                0.0
# 11591516                                                0.0
# 11591517                                                0.0
#
# [1646128 rows x 15 columns]

# %%
y.shape
# Out:
# (233492,)

# %%
df_pivot.shape
# Out:
# (232169, 400)

# %%
# df_pivot.to_csv('../treated_data/pivoted_x.csv',index=False )
# y.to_csv('../treated_data/pivoted_y.csv')

# %%
x = df_pivot.values.reshape((232169,80,5))

# %% [markdown]
# # MODEL

# %%
# df_pivot = pd.read_csv('../treated_data/pivoted_x.csv')
# y = pd.read_csv('../treated_data/pivoted_y.csv')

x = df_pivot.values.reshape((288071,80,5))

# %%
df_pivot

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(10, return_sequences = True),
    tf.keras.layers.LSTM(5, return_sequences = False),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', 
              loss='mean_squared_error', 
              metrics='accuracy')

# %%
history = model.fit(x=X_train, y=y_train, epochs= 60, batch_size=200, validation_data=(X_test,y_test) )
# Out:
# Epoch 1/60
# 778/778 [==============================] - 13s 17ms/step - loss: 0.0109 - accuracy: 0.9870 - val_loss: 0.0100 - val_accuracy: 0.9873
# Epoch 2/60
# 778/778 [==============================] - 13s 16ms/step - loss: 0.0092 - accuracy: 0.9889 - val_loss: 0.0076 - val_accuracy: 0.9909
# Epoch 3/60
# 778/778 [==============================] - 12s 16ms/step - loss: 0.0083 - accuracy: 0.9901 - val_loss: 0.0073 - val_accuracy: 0.9913
# Epoch 4/60
# 778/778 [==============================] - 12s 16ms/step - loss: 0.0072 - accuracy: 0.9915 - val_loss: 0.0067 - val_accuracy: 0.9916
# Epoch 5/60
# 778/778 [==============================] - 12s 16ms/step - loss: 0.0068 - accuracy: 0.9921 - val_loss: 0.0067 - val_accuracy: 0.9917
# Epoch 6/60
# 778/778 [==============================] - 13s 17ms/step - loss: 0.0066 - accuracy: 0.9923 - val_loss: 0.0061 - val_accuracy: 0.9927
# Epoch 7/60
# 778/778 [==============================] - 12s 16ms/step - loss: 0.0060 - accuracy: 0.9930 - val_loss: 0.0062 - val_accuracy: 0.9925
# Epoch 8/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0060 - accuracy: 0.9929 - val_loss: 0.0064 - val_accuracy: 0.9920
# Epoch 9/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0055 - accuracy: 0.9935 - val_loss: 0.0055 - val_accuracy: 0.9939
# Epoch 10/60
# 778/778 [==============================] - 11s 15ms/step - loss: 0.0054 - accuracy: 0.9936 - val_loss: 0.0056 - val_accuracy: 0.9931
# Epoch 11/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0052 - accuracy: 0.9937 - val_loss: 0.0049 - val_accuracy: 0.9942
# Epoch 12/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0051 - accuracy: 0.9938 - val_loss: 0.0048 - val_accuracy: 0.9945
# Epoch 13/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0049 - accuracy: 0.9941 - val_loss: 0.0044 - val_accuracy: 0.9949
# Epoch 14/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0047 - accuracy: 0.9944 - val_loss: 0.0043 - val_accuracy: 0.9950
# Epoch 15/60
# 778/778 [==============================] - 12s 16ms/step - loss: 0.0048 - accuracy: 0.9942 - val_loss: 0.0052 - val_accuracy: 0.9936
# Epoch 16/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0047 - accuracy: 0.9945 - val_loss: 0.0043 - val_accuracy: 0.9952
# Epoch 17/60
# 778/778 [==============================] - 11s 15ms/step - loss: 0.0044 - accuracy: 0.9947 - val_loss: 0.0043 - val_accuracy: 0.9950
# Epoch 18/60
# 778/778 [==============================] - 11s 15ms/step - loss: 0.0045 - accuracy: 0.9946 - val_loss: 0.0041 - val_accuracy: 0.9954
# Epoch 19/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0044 - accuracy: 0.9947 - val_loss: 0.0044 - val_accuracy: 0.9947
# Epoch 20/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0043 - accuracy: 0.9950 - val_loss: 0.0049 - val_accuracy: 0.9942
# Epoch 21/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0042 - accuracy: 0.9949 - val_loss: 0.0047 - val_accuracy: 0.9942
# Epoch 22/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0042 - accuracy: 0.9950 - val_loss: 0.0039 - val_accuracy: 0.9957
# Epoch 23/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0041 - accuracy: 0.9951 - val_loss: 0.0040 - val_accuracy: 0.9952
# Epoch 24/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0041 - accuracy: 0.9951 - val_loss: 0.0037 - val_accuracy: 0.9957
# Epoch 25/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0039 - accuracy: 0.9953 - val_loss: 0.0038 - val_accuracy: 0.9955
# Epoch 26/60
# 778/778 [==============================] - 12s 16ms/step - loss: 0.0039 - accuracy: 0.9954 - val_loss: 0.0037 - val_accuracy: 0.9957
# Epoch 27/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0039 - accuracy: 0.9954 - val_loss: 0.0037 - val_accuracy: 0.9955
# Epoch 28/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0038 - accuracy: 0.9955 - val_loss: 0.0035 - val_accuracy: 0.9959
# Epoch 29/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0037 - accuracy: 0.9956 - val_loss: 0.0036 - val_accuracy: 0.9957
# Epoch 30/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0037 - accuracy: 0.9957 - val_loss: 0.0038 - val_accuracy: 0.9957
# Epoch 31/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0037 - accuracy: 0.9957 - val_loss: 0.0035 - val_accuracy: 0.9959
# Epoch 32/60
# 778/778 [==============================] - 16s 21ms/step - loss: 0.0036 - accuracy: 0.9956 - val_loss: 0.0036 - val_accuracy: 0.9957
# Epoch 33/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0036 - accuracy: 0.9957 - val_loss: 0.0035 - val_accuracy: 0.9960
# Epoch 34/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0035 - accuracy: 0.9958 - val_loss: 0.0034 - val_accuracy: 0.9960
# Epoch 35/60
# 778/778 [==============================] - 15s 20ms/step - loss: 0.0035 - accuracy: 0.9958 - val_loss: 0.0034 - val_accuracy: 0.9960
# Epoch 36/60
# 778/778 [==============================] - 16s 21ms/step - loss: 0.0035 - accuracy: 0.9958 - val_loss: 0.0033 - val_accuracy: 0.9960
# Epoch 37/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0034 - accuracy: 0.9959 - val_loss: 0.0033 - val_accuracy: 0.9961
# Epoch 38/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0034 - accuracy: 0.9959 - val_loss: 0.0032 - val_accuracy: 0.9961
# Epoch 39/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0033 - accuracy: 0.9961 - val_loss: 0.0033 - val_accuracy: 0.9961
# Epoch 40/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0033 - accuracy: 0.9961 - val_loss: 0.0031 - val_accuracy: 0.9963
# Epoch 41/60
# 778/778 [==============================] - 15s 20ms/step - loss: 0.0032 - accuracy: 0.9962 - val_loss: 0.0032 - val_accuracy: 0.9963
# Epoch 42/60
# 778/778 [==============================] - 16s 21ms/step - loss: 0.0032 - accuracy: 0.9961 - val_loss: 0.0030 - val_accuracy: 0.9965
# Epoch 43/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0032 - accuracy: 0.9962 - val_loss: 0.0036 - val_accuracy: 0.9958
# Epoch 44/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0032 - accuracy: 0.9962 - val_loss: 0.0031 - val_accuracy: 0.9963
# Epoch 45/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0031 - accuracy: 0.9963 - val_loss: 0.0030 - val_accuracy: 0.9965
# Epoch 46/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0031 - accuracy: 0.9962 - val_loss: 0.0029 - val_accuracy: 0.9966
# Epoch 47/60
# 778/778 [==============================] - 15s 20ms/step - loss: 0.0030 - accuracy: 0.9963 - val_loss: 0.0030 - val_accuracy: 0.9964
# Epoch 48/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0030 - accuracy: 0.9965 - val_loss: 0.0028 - val_accuracy: 0.9966
# Epoch 49/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0030 - accuracy: 0.9965 - val_loss: 0.0036 - val_accuracy: 0.9958
# Epoch 50/60
# 778/778 [==============================] - 15s 20ms/step - loss: 0.0030 - accuracy: 0.9964 - val_loss: 0.0030 - val_accuracy: 0.9965
# Epoch 51/60
# 778/778 [==============================] - 16s 20ms/step - loss: 0.0030 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 0.9963
# Epoch 52/60
# 778/778 [==============================] - 15s 20ms/step - loss: 0.0030 - accuracy: 0.9965 - val_loss: 0.0028 - val_accuracy: 0.9966
# Epoch 53/60
# 778/778 [==============================] - 13s 17ms/step - loss: 0.0029 - accuracy: 0.9965 - val_loss: 0.0029 - val_accuracy: 0.9966
# Epoch 54/60
# 778/778 [==============================] - 15s 19ms/step - loss: 0.0029 - accuracy: 0.9966 - val_loss: 0.0029 - val_accuracy: 0.9966
# Epoch 55/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0028 - accuracy: 0.9966 - val_loss: 0.0029 - val_accuracy: 0.9966
# Epoch 56/60
# 778/778 [==============================] - 8s 11ms/step - loss: 0.0030 - accuracy: 0.9965 - val_loss: 0.0028 - val_accuracy: 0.9966
# Epoch 57/60
# 778/778 [==============================] - 11s 14ms/step - loss: 0.0029 - accuracy: 0.9967 - val_loss: 0.0027 - val_accuracy: 0.9968
# Epoch 58/60
# 778/778 [==============================] - 10s 12ms/step - loss: 0.0028 - accuracy: 0.9966 - val_loss: 0.0027 - val_accuracy: 0.9968
# Epoch 59/60
# 778/778 [==============================] - 10s 12ms/step - loss: 0.0028 - accuracy: 0.9967 - val_loss: 0.0027 - val_accuracy: 0.9969
# Epoch 60/60
# 778/778 [==============================] - 12s 15ms/step - loss: 0.0028 - accuracy: 0.9967 - val_loss: 0.0029 - val_accuracy: 0.9966

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,61)
plt.plot(epochs, loss_train, 'g', label='Training acc')
plt.plot(epochs, loss_val, 'b', label='validation acc')
plt.title('Training and Validation acc')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.predict(X_test).mean()
# Out:
# 0.10348974
